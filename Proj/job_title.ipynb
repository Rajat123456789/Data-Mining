# %%
import requests
import json
import pandas as pd

df = pd.read_csv('simplify_all_jobs.csv')

for index, row in df.head(10).iterrows():

    company_link = row['url_safe_slug']
    company_id = row['id']
    new_url = f"https://simplify.jobs/c/{company_link}"

    headers = {
        "Content-Type": "application/json",
        "Accept": "application/json, text/plain, /",
        "Origin": "https://simplify.jobs/",
        "Referer": "https://simplify.jobs/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
    }

    for page in range(1, 2):
        url = "https://xv95tgzrem61cja4p.a1.typesense.net/multi_search?x-typesense-api-key=sUjQlkfBFnglUFcsFsZVcE7xhI8lJ1RG"
        payload = {
            "searches": [
                {
                    "query_by": "title,company_name,locations",
                    "per_page": 1,
                    "highlight_full_fields": "title,company_name,locations",
                    "collection": "jobs",
                    "q": "",
                    "facet_by": "company_id,degrees,experience_level,functions,locations",
                    "filter_by": f"company_id:={company_id}",
                    "max_facet_values": 10,
                    "page": 1
                },
                {
                    "query_by": "title,company_name,locations",
                    "per_page": 1,
                    "highlight_full_fields": "title,company_name,locations",
                    "collection": "jobs",
                    "q": "",
                    "facet_by": "company_id",
                    "max_facet_values": 10,
                    "page": 1
                }
            ]
        }
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        if len(response.json()['results'][0]['hits']) > 0:
            titles = [
                hit["document"]["title"]
                for hit in response.json()["results"][0]["hits"]
            ]
            print("\nJob Titles:")
            for title in titles:
                print(title)
        else:
            print(f"{company_link} : No jobs found")
# Out:
# Job Titles:
# Senior Manager - Enterprise Commercial Operations
#
# Job Titles:
# Senior Infrastructure Engineer
#
# Job Titles:
# People Operations Specialist
# Arctic-Wolf : No jobs found
#
# Job Titles:
# Summer Engineering Intern
# Argo-AI : No jobs found
#
# Job Titles:
# Backend Engineer - API
#
# Job Titles:
# Payroll/GL Accountant
# Aritzia : No jobs found
# Armorblox : No jobs found

# %%
import requests
import json
import pandas as pd

df = pd.read_csv('simplify_all_jobs.csv')

for index, row in df.head(10).iterrows():

    company_link = row['url_safe_slug']
    company_id = row['id']
    new_url = f"https://simplify.jobs/c/{company_link}"

    headers = {
        "Content-Type": "application/json",
        "Accept": "application/json, text/plain, /",
        "Origin": "https://simplify.jobs/",
        "Referer": "https://simplify.jobs/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
    }

    for page in range(1, 2):
        url = "https://xv95tgzrem61cja4p.a1.typesense.net/multi_search?x-typesense-api-key=sUjQlkfBFnglUFcsFsZVcE7xhI8lJ1RG"
        payload = {
            "searches": [
                {
                    "query_by": "title,company_name,locations",
                    "per_page": 1,
                    "highlight_full_fields": "title,company_name,locations",
                    "collection": "jobs",
                    "q": "",
                    "facet_by": "company_id,degrees,experience_level,functions,locations",
                    "filter_by": f"company_id:={company_id}",
                    "max_facet_values": 10,
                    "page": 1
                },
                {
                    "query_by": "title,company_name,locations",
                    "per_page": 1,
                    "highlight_full_fields": "title,company_name,locations",
                    "collection": "jobs",
                    "q": "",
                    "facet_by": "company_id",
                    "max_facet_values": 10,
                    "page": 1
                }
            ]
        }
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        if len(response.json()['results'][0]['hits']) > 0:
            company_name = response.json()['results'][0]['hits'][0]["document"]["company_name"]
            titles = [
                hit["document"]["title"]
                for hit in response.json()["results"][0]["hits"]
            ]
            print(f"\nCompany: {company_name}")
            print("Job Titles:")
            for title in titles:
                print(title)
        else:
            print(f"{company_link} : No jobs found")
# Out:
# Company: Arcadia
# Job Titles:
# Senior Manager - Enterprise Commercial Operations
#
# Company: Archive
# Job Titles:
# Senior Infrastructure Engineer
#
# Company: Arc Technologies
# Job Titles:
# People Operations Specialist
# Arctic-Wolf : No jobs found
#
# Company: Arena Club
# Job Titles:
# Summer Engineering Intern
# Argo-AI : No jobs found
#
# Company: Argyle
# Job Titles:
# Backend Engineer - API
#
# Company: Arine
# Job Titles:
# Payroll/GL Accountant
# Aritzia : No jobs found
# Armorblox : No jobs found

# %%
import requests
import json
import pandas as pd

df = pd.read_csv('simplify_all_jobs.csv')

for index, row in df.head(10).iterrows():

    company_link = row['url_safe_slug']
    company_id = row['id']
    new_url = f"https://simplify.jobs/c/{company_link}"

    headers = {
        "Content-Type": "application/json",
        "Accept": "application/json, text/plain, /",
        "Origin": "https://simplify.jobs/",
        "Referer": "https://simplify.jobs/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
    }

    for page in range(1, 2):
        url = "https://xv95tgzrem61cja4p.a1.typesense.net/multi_search?x-typesense-api-key=sUjQlkfBFnglUFcsFsZVcE7xhI8lJ1RG"
        payload = {
            "searches": [
                {
                    "query_by": "title,company_name,locations",
                    "per_page": 1,
                    "highlight_full_fields": "title,company_name,locations",
                    "collection": "jobs",
                    "q": "",
                    "facet_by": "company_id,degrees,experience_level,functions,locations",
                    "filter_by": f"company_id:={company_id}",
                    "max_facet_values": 10,
                    "page": 1
                },
                {
                    "query_by": "title,company_name,locations",
                    "per_page": 1,
                    "highlight_full_fields": "title,company_name,locations",
                    "collection": "jobs",
                    "q": "",
                    "facet_by": "company_id",
                    "max_facet_values": 10,
                    "page": 1
                }
            ]
        }
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        if len(response.json()['results'][0]['hits']) > 0:
            company_name = response.json()['results'][0]['hits'][0]["document"]["company_name"]
            print(f"\nCompany: {company_name}")
            print("Job Titles:")
            for hit in response.json()["results"][0]["hits"]:
                title = hit["document"]["title"]
                print(title)
        else:
            print(f"{company_link} : No jobs found")
# Out:
# Company: Arcadia
# Job Titles:
# Senior Manager - Enterprise Commercial Operations
#
# Company: Archive
# Job Titles:
# Senior Infrastructure Engineer
#
# Company: Arc Technologies
# Job Titles:
# People Operations Specialist
# Arctic-Wolf : No jobs found
#
# Company: Arena Club
# Job Titles:
# Summer Engineering Intern
# Argo-AI : No jobs found
#
# Company: Argyle
# Job Titles:
# Backend Engineer - API
#
# Company: Arine
# Job Titles:
# Payroll/GL Accountant
# Aritzia : No jobs found
# Armorblox : No jobs found

# %%
import requests
import json
import pandas as pd

df = pd.read_csv('simplify_all_jobs.csv')

for index, row in df.head(10).iterrows():

    company_link = row['url_safe_slug']
    company_id = row['id']
    new_url = f"https://simplify.jobs/c/{company_link}"

    headers = {
        "Content-Type": "application/json",
        "Accept": "application/json, text/plain, /",
        "Origin": "https://simplify.jobs/",
        "Referer": "https://simplify.jobs/",
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36"
    }

    for page in range(1, 2):
        url = "https://xv95tgzrem61cja4p.a1.typesense.net/multi_search?x-typesense-api-key=sUjQlkfBFnglUFcsFsZVcE7xhI8lJ1RG"
        payload = {
            "searches": [
                {
                    "query_by": "title,company_name,locations",
                    "per_page": 1,
                    "highlight_full_fields": "title,company_name,locations",
                    "collection": "jobs",
                    "q": "",
                    "facet_by": "company_id,degrees,experience_level,functions,locations",
                    "filter_by": f"company_id:={company_id}",
                    "max_facet_values": 10,
                    "page": 1
                },
                {
                    "query_by": "title,company_name,locations",
                    "per_page": 1,
                    "highlight_full_fields": "title,company_name,locations",
                    "collection": "jobs",
                    "q": "",
                    "facet_by": "company_id",
                    "max_facet_values": 10,
                    "page": 1
                }
            ]
        }
        response = requests.post(url, headers=headers, data=json.dumps(payload))

        if len(response.json()['results'][0]['hits']) > 0:
            company_name = response.json()['results'][0]['hits'][0]["document"]["company_name"]
            print(f"\nCompany: {company_name}")
            print("Job Titles:")
            for hit in response.json()["results"][0]["hits"]:
                title = hit["document"]["title"]
                print(title)
        else:
            print(f"{company_link} : No jobs found")
# Out:
# Company: Arcadia
# Job Titles:
# Senior Manager - Enterprise Commercial Operations
#
# Company: Archive
# Job Titles:
# Senior Infrastructure Engineer
#
# Company: Arc Technologies
# Job Titles:
# People Operations Specialist
# Arctic-Wolf : No jobs found
#
# Company: Arena Club
# Job Titles:
# Summer Engineering Intern
# Argo-AI : No jobs found
#
# Company: Argyle
# Job Titles:
# Backend Engineer - API
#
# Company: Arine
# Job Titles:
# Payroll/GL Accountant
# Aritzia : No jobs found
# Armorblox : No jobs found
