# %%
import pandas as pd

# %%
h1b_df = pd.read_csv('h1b_grader_2024.csv')
h1b_df
# Out:
#       count              employer_name  \
# 0       846                 GOOGLE LLC
# 1       678    AMAZON.COM SERVICES LLC
# 2       609         META PLATFORMS INC
# 3       593                  APPLE INC
# 4       365       ERNST & YOUNG US LLP
# ...     ...                        ...
# 4068      1                 REPSLY INC
# 4069      1              SPRINTRAY INC
# 4070      1        O2 TECHNOLOGIES INC
# 4071      1  AMERICAN IT SOLUTIONS INC
# 4072      1     XCEL LIFE SCIENCES LLC
#
#                                            employer_url
# 0                   /h1b-sponsors/google-llc-em2mg7pj21
# 1     /h1b-sponsors/amazon-dot-com-services-llc-x237...
# 2           /h1b-sponsors/meta-platforms-inc-w2xp7xj6k3
# 3                    /h1b-sponsors/apple-inc-6g06vq412q
# 4       /h1b-sponsors/ernst-and-young-us-llp-v82worplk1
# ...                                                 ...
# 4068                /h1b-sponsors/repsly-inc-6g06joqq2q
# ...

# %%
h1b_df
# Out:
#       count              employer_name  \
# 0       846                 GOOGLE LLC
# 1       678    AMAZON.COM SERVICES LLC
# 2       609         META PLATFORMS INC
# 3       593                  APPLE INC
# 4       365       ERNST & YOUNG US LLP
# ...     ...                        ...
# 4068      1                 REPSLY INC
# 4069      1              SPRINTRAY INC
# 4070      1        O2 TECHNOLOGIES INC
# 4071      1  AMERICAN IT SOLUTIONS INC
# 4072      1     XCEL LIFE SCIENCES LLC
#
#                                            employer_url
# 0                   /h1b-sponsors/google-llc-em2mg7pj21
# 1     /h1b-sponsors/amazon-dot-com-services-llc-x237...
# 2           /h1b-sponsors/meta-platforms-inc-w2xp7xj6k3
# 3                    /h1b-sponsors/apple-inc-6g06vq412q
# 4       /h1b-sponsors/ernst-and-young-us-llp-v82worplk1
# ...                                                 ...
# 4068                /h1b-sponsors/repsly-inc-6g06joqq2q
# ...

# %%
h1b_df['employer_url'] = 'https://h1bgrader.com' + h1b_df['employer_url']

# %%
h1b_df
# Out:
#       count              employer_name  \
# 0       846                 GOOGLE LLC
# 1       678    AMAZON.COM SERVICES LLC
# 2       609         META PLATFORMS INC
# 3       593                  APPLE INC
# 4       365       ERNST & YOUNG US LLP
# ...     ...                        ...
# 4068      1                 REPSLY INC
# 4069      1              SPRINTRAY INC
# 4070      1        O2 TECHNOLOGIES INC
# 4071      1  AMERICAN IT SOLUTIONS INC
# 4072      1     XCEL LIFE SCIENCES LLC
#
#                                            employer_url
# 0     https://h1bgrader.com/h1b-sponsors/google-llc-...
# 1     https://h1bgrader.com/h1b-sponsors/amazon-dot-...
# 2     https://h1bgrader.com/h1b-sponsors/meta-platfo...
# 3     https://h1bgrader.com/h1b-sponsors/apple-inc-6...
# 4     https://h1bgrader.com/h1b-sponsors/ernst-and-y...
# ...                                                 ...
# 4068  https://h1bgrader.com/h1b-sponsors/repsly-inc-...
# ...

# %%
import pandas as pd

# Assuming h1b_df is your DataFrame and it's already created and filled with data

# Save the DataFrame to a CSV file
h1b_df.to_csv('h1b_data.csv', index=False)  # Set index=False if you don't want to save the index in the file

# %%
import requests

url = "https://h1bgrader.com/api/salaries"

headers = {
    "Accept": "application/json, text/javascript, */*; q=0.01",
    "Accept-Language": "en-US,en;q=0.9",
    "Content-Type": "application/x-www-form-urlencoded; charset=UTF-8",
    "Sec-CH-UA": "\"Chromium\";v=\"122\", \"Not(A:Brand\";v=\"24\", \"Google Chrome\";v=\"122\"",
    "Sec-CH-UA-Arch": "\"x86\"",
    "Sec-CH-UA-Bitness": "\"64\"",
    "Sec-CH-UA-Full-Version": "\"122.0.6261.111\"",
    "Sec-CH-UA-Full-Version-List": "\"Chromium\";v=\"122.0.6261.111\", \"Not(A:Brand\";v=\"24.0.0.0\", \"Google Chrome\";v=\"122.0.6261.111\"",
    "Sec-CH-UA-Mobile": "?0",
    "Sec-CH-UA-Model": "",
    "Sec-CH-UA-Platform": "\"Windows\"",
    "Sec-CH-UA-Platform-Version": "\"15.0.0\"",
    "Sec-Fetch-Dest": "empty",
    "Sec-Fetch-Mode": "cors",
    "Sec-Fetch-Site": "same-origin",
    "X-Requested-With": "XMLHttpRequest",
}

# URL encoding the body manually might be necessary if you're directly converting complex nested data structures.
# For simpler data, you can use the 'data' parameter with a dictionary in requests.
data = {
    "draw": "1",
    "columns[0][data]": "_id",
    "columns[0][name]": "",
    "columns[0][searchable]": "true",
    "columns[0][orderable]": "false",
    "columns[1][data]": "_id",
    "columns[1][name]": "",
    "columns[1][searchable]": "true",
    "columns[1][orderable]": "false",
    "columns[2][data]": "_id",
    "columns[2][name]": "",
    "columns[2][searchable]": "true",
    "columns[2][orderable]": "false",
    "columns[3][data]": "_id",
    "columns[3][name]": "",
    "columns[3][searchable]": "true",
    "columns[3][orderable]": "false",
    "start": "0",
    "length": "200",
    "search[value]": "",
    "search[regex]": "false",
    "employer": "Google LLC",
    "year": "2024",
}

response = requests.post(url, headers=headers, data=data)

print(response.text)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js ie6 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 7]>    <html class="no-js ie7 oldie" lang="en-US"> <![endif]-->
# <!--[if IE 8]>    <html class="no-js ie8 oldie" lang="en-US"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-US"> <!--<![endif]-->
# <head>
# <title>Attention Required! | Cloudflare</title>
# <meta charset="UTF-8" />
# <meta http-equiv="Content-Type" content="text/html; charset=UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# <meta name="robots" content="noindex, nofollow" />
# <meta name="viewport" content="width=device-width,initial-scale=1" />
# <link rel="stylesheet" id="cf_styles-css" href="/cdn-cgi/styles/cf.errors.css" />
# <!--[if lt IE 9]><link rel="stylesheet" id='cf_styles-ie-css' href="/cdn-cgi/styles/cf.errors.ie.css" /><![endif]-->
# <style>body{margin:0;padding:0}</style>
#
#
# <!--[if gte IE 10]><!-->
# <script>
#   if (!navigator.cookieEnabled) {
# ...

# %%
import requests

url = "https://h1bgrader.com/api/salaries"

payload = "draw=1&columns%5B0%5D%5Bdata%5D=_id&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=false&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=_id&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=false&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=_id&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=false&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=_id&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=false&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5
ring_domain%22%3A%20%22www.google.com%22%2C%22__mps%22%3A%20%7B%7D%2C%22__mpso%22%3A%20%7B%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fwww.google.com%2F%22%2C%22%24initial_referring_domain%22%3A%20%22www.google.com%22%7D%2C%22__mpus%22%3A%20%7B%7D%2C%22__mpa%22%3A%20%7B%7D%2C%22__mpu%22%3A%20%7B%7D%2C%22__mpr%22%3A%20%5B%5D%2C%22__mpap%22%3A%20%5B%5D%7D; _ga=GA1.2.926277298.1708198584; _gat_UA-130173586-1=1',
  'origin': 'https://h1bgrader.com',
  'referer': 'https://h1bgrader.com/h1b-sponsors/ibm-corporation-l9k5w7nrk1',
  'sec-ch-ua': '"Chromium";v="122", "Not(A:Brand";v="24", "Google Chrome";v="122"',
  'sec-ch-ua-arch': '"x86"',
  'sec-ch-ua-bitness': '"64"',
  'sec-ch-ua-full-version': '"122.0.6261.111"',
  'sec-ch-ua-full-version-list': '"Chromium";v="122.0.6261.111", "Not(A:Brand";v="24.0.0.0", "Google Chrome";v="122.0.6261.111"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-model': '""',
  'sec-ch-ua-platform': '"Windows"',
  'sec-ch-ua-platform-version': '"15.0.0"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
  'x-requested-with': 'XMLHttpRequest'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"draw":1,"recordsFiltered":211,"recordsTotal":211,"data":[{"_id":{"job_title":"DIRECTOR IBM CLOUD VPC NETWORKING","employer_name":"IBM CORPORATION"},"maxWage":398499,"minWage":398499,"avgWage":398499,"count":1,"job_url":"/job-titles/director-ibm-cloud-vpc-networking-30q4o69gkq"},{"_id":{"job_title":"DIGITAL BANKING CONSULTANT","employer_name":"IBM CORPORATION"},"maxWage":323920,"minWage":323920,"avgWage":323920,"count":1,"job_url":"/job-titles/digital-banking-consultant-m2m61z1501"},{"_id":{"job_title":"SOFTWARE DEVELOPMENT MANAGER","employer_name":"IBM CORPORATION"},"maxWage":302749,"minWage":302749,"avgWage":302749,"count":1,"job_url":"/job-titles/software-development-manager-vx233jqx2g"},{"_id":{"job_title":"NA & COMMUNICATIONS MARKET SALESFORCE LEAD ARCHITECT","employer_name":"IBM CORPORATION"},"maxWage":289719,"minWage":289719,"avgWage":289719,"count":1,"job_url":"/job-titles/na-and-communications-market-salesforce-lead-architect-10j7rm650v"},{"_id":{"job_title":"PRINCIPAL M&A 
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("h1bgrader.com")
payload = "draw=1&columns%5B0%5D%5Bdata%5D=_id&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=false&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=_id&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=false&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=_id&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=false&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5
24search_engine%22%3A%20%22google%22%2C%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fwww.google.com%2F%22%2C%22%24initial_referring_domain%22%3A%20%22www.google.com%22%2C%22__mps%22%3A%20%7B%7D%2C%22__mpso%22%3A%20%7B%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fwww.google.com%2F%22%2C%22%24initial_referring_domain%22%3A%20%22www.google.com%22%7D%2C%22__mpus%22%3A%20%7B%7D%2C%22__mpa%22%3A%20%7B%7D%2C%22__mpu%22%3A%20%7B%7D%2C%22__mpr%22%3A%20%5B%5D%2C%22__mpap%22%3A%20%5B%5D%7D; _ga=GA1.2.926277298.1708198584; _gat_UA-130173586-1=1',
  'origin': 'https://h1bgrader.com',
  'referer': 'https://h1bgrader.com/h1b-sponsors/ibm-corporation-l9k5w7nrk1',
  'sec-ch-ua': '"Chromium";v="122", "Not(A:Brand";v="24", "Google Chrome";v="122"',
  'sec-ch-ua-arch': '"x86"',
  'sec-ch-ua-bitness': '"64"',
  'sec-ch-ua-full-version': '"122.0.6261.111"',
  'sec-ch-ua-full-version-list': '"Chromium";v="122.0.6261.111", "Not(A:Brand";v="24.0.0.0", "Google Chrome";v="122.0.6261.111"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-model': '""',
  'sec-ch-ua-platform': '"Windows"',
  'sec-ch-ua-platform-version': '"15.0.0"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
  'x-requested-with': 'XMLHttpRequest'
}
conn.request("POST", "/api/salaries", payload, headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# {"draw":1,"recordsFiltered":211,"recordsTotal":211,"data":[{"_id":{"job_title":"DIRECTOR IBM CLOUD VPC NETWORKING","employer_name":"IBM CORPORATION"},"maxWage":398499,"minWage":398499,"avgWage":398499,"count":1,"job_url":"/job-titles/director-ibm-cloud-vpc-networking-30q4o69gkq"},{"_id":{"job_title":"DIGITAL BANKING CONSULTANT","employer_name":"IBM CORPORATION"},"maxWage":323920,"minWage":323920,"avgWage":323920,"count":1,"job_url":"/job-titles/digital-banking-consultant-m2m61z1501"},{"_id":{"job_title":"SOFTWARE DEVELOPMENT MANAGER","employer_name":"IBM CORPORATION"},"maxWage":302749,"minWage":302749,"avgWage":302749,"count":1,"job_url":"/job-titles/software-development-manager-vx233jqx2g"},{"_id":{"job_title":"NA & COMMUNICATIONS MARKET SALESFORCE LEAD ARCHITECT","employer_name":"IBM CORPORATION"},"maxWage":289719,"minWage":289719,"avgWage":289719,"count":1,"job_url":"/job-titles/na-and-communications-market-salesforce-lead-architect-10j7rm650v"},{"_id":{"job_title":"PRINCIPAL M&A 
# ...

# %%
import requests

url = "https://h1bgrader.com/api/salaries"

# Convert your URL-encoded payload into a dictionary
payload = {
    "draw": "1",
    "columns[0][data]": "_id",
    "columns[0][name]": "",
    "columns[0][searchable]": "true",
    "columns[0][orderable]": "false",
    "columns[0][search][value]": "",
    "columns[0][search][regex]": "false",
    "columns[1][data]": "_id",
    "columns[1][name]": "",
    "columns[1][searchable]": "true",
    "columns[1][orderable]": "false",
    "columns[1][search][value]": "",
    "columns[1][search][regex]": "false",
    "columns[2][data]": "_id",
    "columns[2][name]": "",
    "columns[2][searchable]": "true",
    "columns[2][orderable]": "false",
    "columns[2][search][value]": "",
    "columns[2][search][regex]": "false",
    "columns[3][data]": "_id",
    "columns[3][name]": "",
    "columns[3][searchable]": "true",
    "columns[3][orderable]": "false",
    "columns[3][search][value]": "",
    "columns[3][search][regex]": "false",
    "start": "0",
    "length": "200",
    "search[value]": "",
    "search[regex]": "false",
    "employer": "Google LLC",
    "year": "2024"
}

headers = {
    'authority': 'h1bgrader.com',
    'accept': 'application/json, text/javascript, */*; q=0.01',
    'accept-language': 'en-US,en;q=0.9',
    'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'cookie': '_gid=GA1.2.416590495.1710152407; usprivacy=1YNY; _li_dcdm_c=.h1bgrader.com; _lc2_fpi=a1e786733b42--01hrpgdqbtgcwc1prha22zz20b; _lc2_fpi_meta=%7B%22w%22%3A1710152408443%7D; _lr_retry_request=true; _lr_env_src_ats=false; panoramaId_expiry=1710757208697; _cc_id=71393f040c336921b318a7d1bac9c803; panoramaId=14658000deb00cdfe5421270d93e16d539382c0bf5f9a5fd4072ad6b85069227; ccuid=272b1be3-def7-4b8b-b982-4a816bd41782; cf_chl_3=ea87950737591eb; cf_clearance=KO23eUXlYETN.ICB8RsU32_p7leh.8m4h6mAUjtPUGA-1710153321-1.0.1.1-OdrBVLZHqRYD3iAA8dCVKbalCdi.tEA5G5VF6Ze0VeyRLcGTwp32QlsmtA9WQENYyZNWmIy8pIZRzcODmnrkpQ; cto_bundle=; cto_bidid=wE80qV80UVZzenl1SiUyQlFkVmtqOVR6dE9YSDBReTdybVN5MTFWNHk4MTV2R2taR01lcFhqZUpScTRURm1VRGNCRUNVd1lGREFPWWFsQzdPSEc3M2twZCUyRjFpclJGR0drQjN5VGZxMUJiYVVaT2xnd0ElM0Q; ccsid=469e0620-7ceb-43eb-b321-bbc130ab71d2; _ga_FQCGQZP8BF=GS1.1.1710152407.1.1.1710154177.7.0.0; mp_79dd0f285a9c72f4bcdab6cf2346014e_mixpanel=%7B%22distinct_id%22%3A%20%22%24device%3A18e2d06d83a6d8-0b3b2150d2e569-26001b51-1fa400-18e2d06d83a6d8%22%2C%22%24device_id%22%3A%20%2218e2d06d83a6d8-0b3b2150d2e569-26001b51-1fa400-18e2d06d83a6d8%22%2C%22%24search_engine%22%3A%20%22google%22%2C%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fh1bgrader.com%2Fh1b-sponsors%2Fgoogle-llc-em2mg7pj21%3F__cf_chl_tk%3D37yYD2.6xStYHsdzInixFsN41IM9Zt6nLkv5ePPxgoM-1710152401-0.0.1.1-1599%22%2C%22%24initial_referring_domain%22%3A%20%22h1bgrader.com%22%2C%22__mps%22%3A%20%7B%7D%2C%22__mpso%22%3A%20%7B%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fh1bgrader.com%2Fh1b-sponsors%2Fgoogle-llc-em2mg7pj21%3F__cf_chl_tk%3D37yYD2.6xStYHsdzInixFsN41IM9Zt6nLkv5ePPxgoM-1710152401-0.0.1.1-1599%22%2C%22%24initial_referring_domain%22%3A%20%22h1bgrader.com%22%7D%2C%22__mpus%22%3A%20%7B%7D%2C%22__mpa%22%3A%20%7B%7D%2C%22__mpu%22%3A%20%7B%7D%2C%22__mpr%22%3A%20%5B%5D%2C%22__mpap%22%3A%20%5B%5D%7D; _ga=GA1.2.1631438351.1710152407; _gat_UA-130173586-1=1',
    'referer': 'https://h1bgrader.com/h1b-sponsors/ibm-corporation-l9k5w7nrk1',
    'sec-ch-ua': '"Chromium";v="122", "Not(A:Brand";v="24", "Google Chrome";v="122"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"122.0.6261.111"',
    'sec-ch-ua-full-version-list': '"Chromium";v="122.0.6261.111", "Not(A:Brand";v="24.0.0.0", "Google Chrome";v="122.0.6261.111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"15.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}

# Make sure to replace 'your_cookie_string_here' with the actual cookie string.
response = requests.post(url, headers=headers, data=payload)

print(response.text)
# Out:
# {"draw":1,"recordsFiltered":143,"recordsTotal":143,"data":[{"_id":{"job_title":"DIRECTOR PRODUCT MARKETING MANAGEMENT","employer_name":"GOOGLE LLC"},"maxWage":375000,"minWage":375000,"avgWage":375000,"count":1,"job_url":"/job-titles/director-product-marketing-management-dvk4noz60w"},{"_id":{"job_title":"DIRECTOR MARKETING CREATIVE & PRODUCER","employer_name":"GOOGLE LLC"},"maxWage":331000,"minWage":331000,"avgWage":331000,"count":1,"job_url":"/job-titles/director-marketing-creative-and-producer-x237m7zvkg"},{"_id":{"job_title":"UX DIRECTOR","employer_name":"GOOGLE LLC"},"maxWage":324000,"minWage":324000,"avgWage":324000,"count":1,"job_url":"/job-titles/ux-director-6g063z5p0q"},{"_id":{"job_title":"DIRECTOR PRODUCT MANAGEMENT","employer_name":"GOOGLE LLC"},"maxWage":318000,"minWage":318000,"avgWage":318000,"count":1,"job_url":"/job-titles/director-product-management-5g2remz30l"},{"_id":{"job_title":"PRODUCT MARKETING MANAGER","employer_name":"GOOGLE LLC"},"maxWage":288000,"minWage":28
# ...

# %%
import requests
import json

# Your setup code (url, payload, and headers) goes here

# Sending the POST request
response = requests.post(url, headers=headers, data=payload)

# Converting the response to JSON
response_json = response.json()

# Pretty-printing the JSON data
print(json.dumps(response_json, indent=4))
# Out:
# {
#     "draw": 1,
#     "recordsFiltered": 143,
#     "recordsTotal": 143,
#     "data": [
#         {
#             "_id": {
#                 "job_title": "DIRECTOR PRODUCT MARKETING MANAGEMENT",
#                 "employer_name": "GOOGLE LLC"
#             },
#             "maxWage": 375000,
#             "minWage": 375000,
#             "avgWage": 375000,
#             "count": 1,
#             "job_url": "/job-titles/director-product-marketing-management-dvk4noz60w"
#         },
#         {
#             "_id": {
#                 "job_title": "DIRECTOR MARKETING CREATIVE & PRODUCER",
#                 "employer_name": "GOOGLE LLC"
#             },
#             "maxWage": 331000,
#             "minWage": 331000,
#             "avgWage": 331000,
#             "count": 1,
#             "job_url": "/job-titles/director-marketing-creative-and-producer-x237m7zvkg"
#         },
#         {
#             "_id": {
#                 "job_title": "UX DIRECTOR",
# ...

# %%
import requests

cookies = {
    '_gid': 'GA1.2.416590495.1710152407',
    'usprivacy': '1YNY',
    '_li_dcdm_c': '.h1bgrader.com',
    '_lc2_fpi': 'a1e786733b42--01hrpgdqbtgcwc1prha22zz20b',
    '_lc2_fpi_meta': '%7B%22w%22%3A1710152408443%7D',
    '_lr_retry_request': 'true',
    '_lr_env_src_ats': 'false',
    'panoramaId_expiry': '1710757208697',
    '_cc_id': '71393f040c336921b318a7d1bac9c803',
    'panoramaId': '14658000deb00cdfe5421270d93e16d539382c0bf5f9a5fd4072ad6b85069227',
    'ccuid': '272b1be3-def7-4b8b-b982-4a816bd41782',
    'ccsid': 'e6c9a5a5-a905-475e-9694-1d7e0cbe0649',
    'cto_bundle': '',
    'cto_bidid': 'M_vwrV80UVZzenl1SiUyQlFkVmtqOVR6dE9YSDBReTdybVN5MTFWNHk4MTV2R2taR01lcFhqZUpScTRURm1VRGNCRUNVd1lGREFPWWFsQzdPSEc3M2twZCUyRjFpclg2aDNkWHhuYmlVSUw5ZGx2blAyNkElM0Q',
    'cf_chl_3': 'c9d60565ac94199',
    'cf_clearance': 'GzE8Pe.sVnYMU5lLdx8qtE_n8InxQtYdsN4TB6p7hC0-1710155342-1.0.1.1-xrXIq8s449vgOPtgTdxocgMRaxeU1wxRiWsLehN1aPqxed3.6yT1k7l3svbCtu1LUTDUQVoMP16WQaGZAtiLUw',
    '_ga_FQCGQZP8BF': 'GS1.1.1710152407.1.1.1710155348.54.0.0',
    'mp_79dd0f285a9c72f4bcdab6cf2346014e_mixpanel': '%7B%22distinct_id%22%3A%20%22%24device%3A18e2d06d83a6d8-0b3b2150d2e569-26001b51-1fa400-18e2d06d83a6d8%22%2C%22%24device_id%22%3A%20%2218e2d06d83a6d8-0b3b2150d2e569-26001b51-1fa400-18e2d06d83a6d8%22%2C%22%24search_engine%22%3A%20%22google%22%2C%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fh1bgrader.com%2Fh1b-sponsors%2Fgoogle-llc-em2mg7pj21%3F__cf_chl_tk%3D37yYD2.6xStYHsdzInixFsN41IM9Zt6nLkv5ePPxgoM-1710152401-0.0.1.1-1599%22%2C%22%24initial_referring_domain%22%3A%20%22h1bgrader.com%22%2C%22__mps%22%3A%20%7B%7D%2C%22__mpso%22%3A%20%7B%22%24initial_referrer%22%3A%20%22https%3A%2F%2Fh1bgrader.com%2Fh1b-sponsors%2Fgoogle-llc-em2mg7pj21%3F__cf_chl_tk%3D37yYD2.6xStYHsdzInixFsN41IM9Zt6nLkv5ePPxgoM-1710152401-0.0.1.1-1599%22%2C%22%24initial_referring_domain%22%3A%20%22h1bgrader.com%22%7D%2C%22__mpus%22%3A%20%7B%7D%2C%22__mpa%22%3A%20%7B%7D%2C%22__mpu%22%3A%20%7B%7D%2C%22__mpr%22%3A%20%5B%5D%2C%22__mpap%22%3A%20%5B%5D%7D',
    'origin': 'https://h1bgrader.com',
    'referer': 'https://h1bgrader.com/h1b-sponsors/google-llc-em2mg7pj21',
    'sec-ch-ua': '"Chromium";v="122", "Not(A:Brand";v="24", "Google Chrome";v="122"',
    'sec-ch-ua-arch': '"x86"',
    'sec-ch-ua-bitness': '"64"',
    'sec-ch-ua-full-version': '"122.0.6261.111"',
    'sec-ch-ua-full-version-list': '"Chromium";v="122.0.6261.111", "Not(A:Brand";v="24.0.0.0", "Google Chrome";v="122.0.6261.111"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-model': '""',
    'sec-ch-ua-platform': '"Windows"',
    'sec-ch-ua-platform-version': '"15.0.0"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/122.0.0.0 Safari/537.36',
    'x-requested-with': 'XMLHttpRequest',
}

data = {
    'draw': '1',
    'columns[0][data]': '_id',
    'columns[0][name]': '',
    'columns[0][searchable]': 'true',
    'columns[0][orderable]': 'false',
    'columns[0][search][value]': '',
    'columns[0][search][regex]': 'false',
    'columns[1][data]': '_id',
    'columns[1][name]': '',
    'columns[1][searchable]': 'true',
    'columns[1][orderable]': 'false',
    'columns[1][search][value]': '',
    'columns[1][search][regex]': 'false',
    'columns[2][data]': '_id',
    'columns[2][name]': '',
    'columns[2][searchable]': 'true',
    'columns[2][orderable]': 'false',
    'columns[2][search][value]': '',
    'columns[2][search][regex]': 'false',
    'columns[3][data]': '_id',
    'columns[3][name]': '',
    'columns[3][searchable]': 'true',
    'columns[3][orderable]': 'false',
    'columns[3][search][value]': '',
    'columns[3][search][regex]': 'false',
    'start': '0',
    'length': '200',
    'search[value]': '',
    'search[regex]': 'false',
    'employer': 'Google LLC',
    'year': '2024',
}

response = requests.post('https://h1bgrader.com/api/salaries', cookies=cookies, headers=headers, data=data)
response.text
# Out:
# '<!DOCTYPE html><html lang="en-US"><head><title>Just a moment...</title><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="robots" content="noindex,nofollow"><meta name="viewport" content="width=device-width,initial-scale=1"><style>*{box-sizing:border-box;margin:0;padding:0}html{line-height:1.15;-webkit-text-size-adjust:100%;color:#313131}button,html{font-family:system-ui,-apple-system,BlinkMacSystemFont,Segoe UI,Roboto,Helvetica Neue,Arial,Noto Sans,sans-serif,Apple Color Emoji,Segoe UI Emoji,Segoe UI Symbol,Noto Color Emoji}@media (prefers-color-scheme:dark){body{background-color:#222;color:#d9d9d9}body a{color:#fff}body a:hover{color:#ee730a;text-decoration:underline}body .lds-ring div{border-color:#999 transparent transparent}body .font-red{color:#b20f03}body .big-button,body .pow-button{background-color:#4693ff;color:#1d1d1d}body #challenge-success-text{background-image:url(data:image/svg+xml;base64
# ...

# %%
import requests

url = "https://h1bgrader.com/api/salaries"

payload = "draw=1&columns%5B0%5D%5Bdata%5D=_id&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=false&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5
%22%2C%22__mps%22%3A%20%7B%7D%2C%22__mpso%22%3A%20%7B%22%24initial_referrer%22%3A%20%22%24direct%22%2C%22%24initial_referring_domain%22%3A%20%22%24direct%22%7D%2C%22__mpus%22%3A%20%7B%7D%2C%22__mpa%22%3A%20%7B%7D%2C%22__mpu%22%3A%20%7B%7D%2C%22__mpr%22%3A%20%5B%5D%2C%22__mpap%22%3A%20%5B%5D%2C%22%24search_engine%22%3A%20%22google%22%7D; _ga=GA1.1.1449691352.1708199231; _ga_FQCGQZP8BF=GS1.1.1713857302.15.1.1713857333.29.0.0',
  'origin': 'https://h1bgrader.com',
  'priority': 'u=1, i',
  'referer': 'https://h1bgrader.com/h1b-sponsors/linkedin-corporation-d1k9mo9q0m/salaries',
  'sec-ch-ua': '"Chromium";v="124", "Google Chrome";v="124", "Not-A.Brand";v="99"',
  'sec-ch-ua-arch': '"x86"',
  'sec-ch-ua-bitness': '"64"',
  'sec-ch-ua-full-version': '"124.0.6367.60"',
  'sec-ch-ua-full-version-list': '"Chromium";v="124.0.6367.60", "Google Chrome";v="124.0.6367.60", "Not-A.Brand";v="99.0.0.0"',
  'sec-ch-ua-mobile': '?0',
  'sec-ch-ua-model': '""',
  'sec-ch-ua-platform': '"Windows"',
  'sec-ch-ua-platform-version': '"15.0.0"',
  'sec-fetch-dest': 'empty',
  'sec-fetch-mode': 'cors',
  'sec-fetch-site': 'same-origin',
  'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
  'x-requested-with': 'XMLHttpRequest'
}

response = requests.request("POST", url, headers=headers, data=payload)

print(response.text)
# Out:
# {"draw":1,"recordsFiltered":59,"recordsTotal":59,"data":[{"_id":{"job_title":"PRINCIPAL STAFF SOFTWARE ENGINEER MACHINE LEARNING","employer_name":"LINKEDIN CORPORATION"},"maxWage":289673,"minWage":289673,"avgWage":289673,"count":1,"job_url":"/job-titles/principal-staff-software-engineer-machine-learning-60eq6dzr0z"},{"_id":{"job_title":"PRINCIPAL STAFF SOFTWARE ENGINEER SYSTEMS INFRASTRUCTURE","employer_name":"LINKEDIN CORPORATION"},"maxWage":283442,"minWage":283442,"avgWage":283442,"count":2,"job_url":"/job-titles/principal-staff-software-engineer-systems-infrastructure-60d9m5yxk8"},{"_id":{"job_title":"SR STAFF SOFTWARE ENGINEER SYSTEMS INFRASTRUCTURE","employer_name":"LINKEDIN CORPORATION"},"maxWage":283442,"minWage":283442,"avgWage":283442,"count":1,"job_url":"/job-titles/sr-staff-software-engineer-systems-infrastructure-p0l47wg42l"},{"_id":{"job_title":"SR STAFF SOFTWARE ENGINEER","employer_name":"LINKEDIN CORPORATION"},"maxWage":283442,"minWage":208000,"avgWage":258294.66666666
# ...

# %%
import json

response.text
response_data = json.loads(response.text)

# Pretty-print the JSON data
print(json.dumps(response_data, indent=4))
# Out:
# {
#     "draw": 1,
#     "recordsFiltered": 59,
#     "recordsTotal": 59,
#     "data": [
#         {
#             "_id": {
#                 "job_title": "PRINCIPAL STAFF SOFTWARE ENGINEER MACHINE LEARNING",
#                 "employer_name": "LINKEDIN CORPORATION"
#             },
#             "maxWage": 289673,
#             "minWage": 289673,
#             "avgWage": 289673,
#             "count": 1,
#             "job_url": "/job-titles/principal-staff-software-engineer-machine-learning-60eq6dzr0z"
#         },
#         {
#             "_id": {
#                 "job_title": "PRINCIPAL STAFF SOFTWARE ENGINEER SYSTEMS INFRASTRUCTURE",
#                 "employer_name": "LINKEDIN CORPORATION"
#             },
#             "maxWage": 283442,
#             "minWage": 283442,
#             "avgWage": 283442,
#             "count": 2,
#             "job_url": "/job-titles/principal-staff-software-engineer-systems-infrastructure-60d9m5yxk8"
#         },
#         {
# ...

# %%
len(response_data['data'])
# Out:
# 59

# %%
import pandas as pd

h1b_df = pd.read_csv('h1b_grader_2024.csv')
h1b_df
# Out:
#       count              employer_name                                       employer_url
# 0       846                 GOOGLE LLC                /h1b-sponsors/google-llc-em2mg7pj21
# 1       678    AMAZON.COM SERVICES LLC  /h1b-sponsors/amazon-dot-com-services-llc-x237...
# 2       609         META PLATFORMS INC        /h1b-sponsors/meta-platforms-inc-w2xp7xj6k3
# 3       593                  APPLE INC                 /h1b-sponsors/apple-inc-6g06vq412q
# 4       365       ERNST & YOUNG US LLP    /h1b-sponsors/ernst-and-young-us-llp-v82worplk1
# ...     ...                        ...                                                ...
# 4068      1                 REPSLY INC                /h1b-sponsors/repsly-inc-6g06joqq2q
# 4069      1              SPRINTRAY INC             /h1b-sponsors/sprintray-inc-5g2rmxg8kl
# 4070      1        O2 TECHNOLOGIES INC       /h1b-sponsors/o2-technologies-inc-ew2xpyx6k3
# ...

# %%
all_companies_list = []

for index,each_row in h1b_df.iterrows():
    all_companies_list.append(each_row['employer_name'])
#     print(each_row['employer_name'])

all_companies_list
# Out:
# ['GOOGLE LLC',
#  'AMAZON.COM SERVICES LLC',
#  'META PLATFORMS INC',
#  'APPLE INC',
#  'ERNST & YOUNG US LLP',
#  'EBAY INC',
#  'INTEL CORPORATION',
#  'LINKEDIN CORPORATION',
#  'SALESFORCE INC',
#  'QUALCOMM TECHNOLOGIES INC',
#  'WAL MART ASSOCIATES INC',
#  'NVIDIA CORPORATION',
#  'COGNIZANT TECHNOLOGY SOLUTIONS US CORP',
#  'MICROSOFT CORPORATION',
#  'TESLA INC',
#  'PAYPAL INC',
#  'INFOSYS LIMITED',
#  'AMAZON DEVELOPMENT CENTER US INC',
#  'AMAZON WEB SERVICES INC',
#  'THE LELAND STANFORD JR UNIVERSITY',
#  'BYTEDANCE INC',
#  'CISCO SYSTEMS INC',
#  'UBER TECHNOLOGIES INC',
#  'LUCID USA INC',
#  'RIVIAN AUTOMOTIVE LLC',
#  'SERVICENOW INC',
#  'UNIVERSITY OF CALIFORNIA SAN FRANCISCO',
#  'ADOBE INC',
#  'HCL AMERICA INC',
#  'UNIVERSITY OF CALIFORNIA SAN DIEGO',
#  'TATA CONSULTANCY SERVICES LIMITED',
#  'TIKTOK INC',
#  'THE UNIVERSITY OF SOUTHERN CALIFORNIA',
#  'VMWARE LLC',
#  'DOORDASH INC',
#  'INTUIT INC',
#  'DELOITTE CONSULTING LLP',
# ...

# %%
## Not using this -- Check pointed code

# import requests
# from urllib.parse import unquote, parse_qs, urlencode

# # URL-encoded payload
# payload = """
# draw=1&columns%5B0%5D%5Bdata%5D=_id&columns%5B0%5D%5Bname%5D=&columns%5B0%5D%5Bsearchable%5D=true&columns%5B0%5D%5Borderable%5D=false&columns%5B0%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B0%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B1%5D%5Bdata%5D=_id&columns%5B1%5D%5Bname%5D=&columns%5B1%5D%5Bsearchable%5D=true&columns%5B1%5D%5Borderable%5D=false&columns%5B1%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B1%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B2%5D%5Bdata%5D=_id&columns%5B2%5D%5Bname%5D=&columns%5B2%5D%5Bsearchable%5D=true&columns%5B2%5D%5Borderable%5D=false&columns%5B2%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B2%5D%5Bsearch%5D%5Bregex%5D=false&columns%5B3%5D%5Bdata%5D=_id&columns%5B3%5D%5Bname%5D=&columns%5B3%5D%5Bsearchable%5D=true&columns%5B3%5D%5Borderable%5D=false&columns%5B3%5D%5Bsearch%5D%5Bvalue%5D=&columns%5B3%5D%5Bsearch%5D%5Bregex%5D=false&start=0&length=200&search%5Bvalue%5D=&search%5Bregex%5D=false&employer=Linkedin+Corporation&year=2024
# """

# # Decode the URL-encoded string
# decoded_payload = unquote(payload)

# # Parse the query string into a dictionary
# payload_dict = parse_qs(decoded_payload)

# # Modify the company name in the dictionary
# payload_dict['employer'] = ['Google LLC']  # Change 'New Company Name' to your desired company name

# # Re-encode the modified payload for the POST request
# encoded_payload = urlencode(payload_dict, doseq=True)

# # Print the modified payload
# encoded_payload

# %%
import requests
import json

def fetch_salary_data(employer_name, year):
    url = "https://h1bgrader.com/api/salaries"
    
    payload = {
        'draw': '1',
        'columns[0][data]': '_id',
        'columns[0][name]': '',
        'columns[0][searchable]': 'true',
        'columns[0][orderable]': 'false',
        'columns[0][search][value]': '',
        'columns[0][search][regex]': 'false',
        'columns[1][data]': '_id',
        'columns[1][name]': '',
        'columns[1][searchable]': 'true',
        'columns[1][orderable]': 'false',
        'columns[1][search][value]': '',
        'columns[1][search][regex]': 'false',
        'columns[2][data]': '_id',
        'columns[2][name]': '',
        'columns[2][searchable]': 'true',
        'columns[2][orderable]': 'false',
        'columns[2][search][value]': '',
        'columns[2][search][regex]': 'false',
        'columns[3][data]': '_id',
        'columns[3][name]': '',
        'columns[3][searchable]': 'true',
        'columns[3][orderable]': 'false',
        'columns[3][search][value]': '',
        'columns[3][search][regex]': 'false',
        'start': '0',
        'length': '200',
        'search[value]': '',
        'search[regex]': 'false',
        'employer': employer_name,
        'year': year,
    }
    
    headers = {
        'accept': 'application/json, text/javascript, */*; q=0.01',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8,hi;q=0.7',
        'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest'
    }

    response = requests.post(url, headers=headers, data=payload)
    response_data = response.json()
    
#     print(json.dumps(response_data, indent=4))
    return response_data['data']

# Example usage
fetch_salary_data("AEVA INC", "2024")
# Out:
# [{'_id': {'job_title': 'PRINCIPAL DATA PLATFORM ENGINEER',
#    'employer_name': 'AEVA INC'},
#   'maxWage': 255000,
#   'minWage': 255000,
#   'avgWage': 255000,
#   'count': 1,
#   'job_url': '/job-titles/principal-data-platform-engineer-60d999l6k8'},
#  {'_id': {'job_title': 'AUTOMOTIVE EMBEDDED SOFTWARE ARCHITECT',
#    'employer_name': 'AEVA INC'},
#   'maxWage': 240000,
#   'minWage': 240000,
#   'avgWage': 240000,
#   'count': 1,
#   'job_url': '/job-titles/automotive-embedded-software-architect-9k5n36ryk1'},
#  {'_id': {'job_title': 'SENIOR EMBEDDED SOFTWARE TEST ENGINEER',
#    'employer_name': 'AEVA INC'},
#   'maxWage': 181330,
#   'minWage': 181330,
#   'avgWage': 181330,
#   'count': 1,
#   'job_url': '/job-titles/senior-embedded-software-test-engineer-g06659v30q'},
#  {'_id': {'job_title': 'SENIOR SOC FIRMWARE ENGINEER',
#    'employer_name': 'AEVA INC'},
#   'maxWage': 175000,
#   'minWage': 175000,
#   'avgWage': 175000,
#   'count': 1,
# ...

# %%
import pandas as pd

companywise_jobs_wages_list = []
specific_company = "AEVA INC"

def parse_job_title_and_wages_companywise(data):
    specific_companywise_jobs_wages_list = []
    for each_row in data:
        company_name = each_row["_id"]["employer_name"]
        job_title = each_row["_id"]["job_title"]
        min_wage = each_row["minWage"]
        max_wage = each_row["maxWage"]
        avg_wage = each_row["avgWage"]
        jobs_count = each_row["count"]
        
        companywise_jobs_wages_list.append({
            "Company Name": company_name,
            "Job Title": job_title,
            "Min Wage": min_wage,
            "Max Wage": max_wage,
            "Average Wage": avg_wage,
            "Job Count": jobs_count
        })
        
        specific_companywise_jobs_wages_list.append({
            "Company Name": company_name,
            "Job Title": job_title,
            "Min Wage": min_wage,
            "Max Wage": max_wage,
            "Average Wage": avg_wage,
            "Job Count": jobs_count
        })
        
    return specific_companywise_jobs_wages_list


# Call the function
specific_companywise_jobs_wages_list = parse_job_title_and_wages_companywise(response_data['data'])

# Checking point for debugging
# for item in companywise_jobs_wages_list:
#     print(item)

# Assuming companywise_jobs_wages_list is already filled from the previous code block
df = pd.DataFrame(specific_companywise_jobs_wages_list)

# Display the DataFrame
file_name = f"{specific_company.replace(' ', '_').replace('/', '_').lower()}_wages.csv"

df.to_csv(f'company-wise-job-wages/{file_name}', index=False)

# %%
import requests
import json
import pandas as pd
import os
import time

def fetch_salary_data(employer_name, year):
    url = "https://h1bgrader.com/api/salaries"
    payload = {
        'draw': '1',
        'columns[0][data]': '_id',
        'columns[0][name]': '',
        'columns[0][searchable]': 'true',
        'columns[0][orderable]': 'false',
        'columns[0][search][value]': '',
        'columns[0][search][regex]': 'false',
        'columns[1][data]': '_id',
        'columns[1][name]': '',
        'columns[1][searchable]': 'true',
        'columns[1][orderable]': 'false',
        'columns[1][search][value]': '',
        'columns[1][search][regex]': 'false',
        'columns[2][data]': '_id',
        'columns[2][name]': '',
        'columns[2][searchable]': 'true',
        'columns[2][orderable]': 'false',
        'columns[2][search][value]': '',
        'columns[2][search][regex]': 'false',
        'columns[3][data]': '_id',
        'columns[3][name]': '',
        'columns[3][searchable]': 'true',
        'columns[3][orderable]': 'false',
        'columns[3][search][value]': '',
        'columns[3][search][regex]': 'false',
        'start': '0',
        'length': '200',
        'search[value]': '',
        'search[regex]': 'false',
        'employer': employer_name,
        'year': year,
    }
    headers = {
        'accept': 'application/json, text/javascript, */*; q=0.01',
        'accept-language': 'en-GB,en-US;q=0.9,en;q=0.8,hi;q=0.7',
        'content-type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124.0.0.0 Safari/537.36',
        'x-requested-with': 'XMLHttpRequest'
    }
    response = requests.post(url, headers=headers, data=payload)
    print(response.json()['data'][0])
    return response.json()['data']

def parse_job_title_and_wages_companywise(data):
    companywise_jobs_wages_list = []
    for each_row in data:
        company_name = each_row["_id"]["employer_name"]
        job_title = each_row["_id"]["job_title"]
        min_wage = each_row["minWage"]
        max_wage = each_row["maxWage"]
        avg_wage = each_row["avgWage"]
        jobs_count = each_row["count"]
        companywise_jobs_wages_list.append({
            "Company Name": company_name,
            "Job Title": job_title,
            "Min Wage": min_wage,
            "Max Wage": max_wage,
            "Average Wage": avg_wage,
            "Job Count": jobs_count
        })
    return companywise_jobs_wages_list

def save_data_to_csv(data, filename):
    if os.path.exists(filename):
        print(f"File {filename} already exists. Skipping save.")
    else:
        df = pd.DataFrame(data)
        df.to_csv(filename, index=False)
        print(f"Data saved to {filename}")

def process_company(employer_name, year, retries=3, delay=5):
    directory = "company-wise-job-wages-2023"
    os.makedirs(directory, exist_ok=True)
    file_name = f"{directory}/{employer_name.replace(' ', '_').replace('/', '_').lower()}_wages.csv"
    
    if os.path.exists(file_name):
        print(f"File {file_name} already exists. Skipping fetch and save.")
        return

    attempt = 0
    while attempt < retries:
        try:
            data = fetch_salary_data(employer_name, year)
            parsed_data = parse_job_title_and_wages_companywise(data)
            save_data_to_csv(parsed_data, file_name)
            break  # Break the loop if successful
        except Exception as e:
            attempt += 1
            print(f"Attempt {attempt} failed: {e}")
            if attempt < retries:
                print(f"Retrying in {delay} seconds...")
                time.sleep(delay)
            else:
                print("All attempts failed. Moving on to next company or stopping.")

def run_all_companies(all_companies_list, year):
    for company in all_companies_list:
        process_company(company, year)
    print("Processing complete for all companies.")

# Example usage
if __name__ == "__main__":
    all_companies_list = h1b_df['employer_name'].unique()
    run_all_companies(all_companies_list, "2023")
# Out:
# File company-wise-job-wages-2023/google_llc_wages.csv already exists. Skipping fetch and save.
# File company-wise-job-wages-2023/amazon.com_services_llc_wages.csv already exists. Skipping fetch and save.
# File company-wise-job-wages-2023/meta_platforms_inc_wages.csv already exists. Skipping fetch and save.
# File company-wise-job-wages-2023/apple_inc_wages.csv already exists. Skipping fetch and save.
# File company-wise-job-wages-2023/ernst_&_young_us_llp_wages.csv already exists. Skipping fetch and save.
# File company-wise-job-wages-2023/ebay_inc_wages.csv already exists. Skipping fetch and save.
# File company-wise-job-wages-2023/intel_corporation_wages.csv already exists. Skipping fetch and save.
# File company-wise-job-wages-2023/linkedin_corporation_wages.csv already exists. Skipping fetch and save.
# File company-wise-job-wages-2023/salesforce_inc_wages.csv already exists. Skipping fetch and save.
# ...

# %%
len(all_companies_list)
# Out:
# 4073
